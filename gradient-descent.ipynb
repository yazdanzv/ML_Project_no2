# %% [markdown]
# # Imports
# Run this code to import necessary modules. Note that the functions ``cost_function`` and ``gradient`` imported from module ``gd`` are stubs. You will need to fill in the code in ``gd.py``.

# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2


import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

from gd import cost_function, gradient, explicit_answer  # stubs

# %% [markdown]
# # Create a simple data set
#
# Run this cell to generate and plot some data from the linear model $y \approx -1 + 2x$, that is, $\theta_0 = -1$ and  $\theta_1 = 2$.

# %%
# Set the random seed so the program will always generate the same data
np.random.seed(0)

# Generate n random x values between -5 and 5
n = 20
x = 10 * np.random.rand(n) - 5

# Generate y values from the model y ~= 2x - 1
epsilon = np.random.randn(n)
y = -1 + 2*x + epsilon

plt.plot(x, y, marker='o', linestyle='none')
plt.show()

# %% [markdown]
# # TODO: implement the cost function
# The squared error cost function is
# $$\frac{1}{2} \sum_{i=1}^m \big(h_\theta(x^{(i)}) - y^{(i)}\big)^2.$$
# $$h_\theta(x^{(i)})=\theta_0 + \theta_1 . x^{(i)}$$
# Open the file ``gd.py`` and implement ``cost_function``. Then run this cell to test it out.

# %%
print(cost_function(x, y, 0,  1))   # should print 104.772951994
print(cost_function(x, y, 2, -1))   # should print 744.953822077
print(cost_function(x, y, -1, 2))   # should print 14.090816198
# Out:
# 104.77295199433607
# 744.9538220768486
# 14.090816198013721

# %% [markdown]
# # Plotting setup
# Run this cell. It sets up a routine ``plot_model`` that will be called later to illustrate the progress of gradient descent.

# %%
# Construct a dense grid of (theta_0, theta_1) values
theta0_vals = np.linspace(-10, 10)
theta1_vals = np.linspace(-10, 10)
[THETA0, THETA1] = np.meshgrid(theta0_vals, theta1_vals)

# Define a cost function that has x and y "baked in"
def mycost(theta0, theta1):
    return cost_function(x, y, theta0, theta1)

# Now vectorize this cost function and apply it simultaneously to all
# pairs in dense grid of (theta_0, theta_1) values
mycost_vectorized = np.vectorize(mycost)
J_SURF = mycost_vectorized(THETA0, THETA1)

# Define the test inputs
x_test = np.linspace(-5, 5, 100)

fig = plt.figure(1, figsize=(10,4))

# Create the figure
def init_plot():
    fig.clf()

    # Build left subplot (cost function)
    ax1 = fig.add_subplot(1, 2, 1) 
    ax1.contour(THETA0, THETA1, J_SURF, 20)
    ax1.set_xlabel('Intercept theta_0')
    ax1.set_ylabel('Slope theta_1')
    ax1.set_xlim([-10, 10])
    ax1.set_ylim([-10, 10])

    # The data will be added later for these plot elements:
    line, = ax1.plot([], [])
    dot,  = ax1.plot([], [], marker='o')

    # Build right subplot (data + current hypothesis)
    ax2 = fig.add_subplot(1, 2, 2)
    ax2.plot(x, y, marker='o', linestyle='none') 
    ax2.set_xlim([-6, 6])
    ax2.set_ylim([-10, 10])

    # The data will be added later for this:
    hyp, = ax2.plot( x_test, 0*x_test )
    
    return line, dot, hyp


# Define a function to update the plot
def update_plot(theta_0, theta_1, line, dot, hyp):
    line.set_xdata( np.append(line.get_xdata(), theta_0 ) )
    line.set_ydata( np.append(line.get_ydata(), theta_1 ) )
    dot.set_xdata([theta_0])
    dot.set_ydata([theta_1])
    hyp.set_ydata( theta_0 + theta_1 * x_test )

# %% [markdown]
# # TODO: implement the gradient
# 1. Review the mathematical expressions for $\frac{\partial}{\partial \theta_0} J(\theta_0, \theta_1)$ and $\frac{\partial}{\partial \theta_1} J(\theta_0, \theta_1)$ for our model and cost funtion.
# 1. Implement the function ``gradient`` in ``gd.py`` to return these two partial derivatives.
#
# Then run this cell to test your code:

# %%
print(gradient(np.array([1, 2]), np.array([0, 1]), 0,  1)) # should print (2, 3)
print(gradient(x, y, 0,  1))   # should print (3.569176215534113, -163.58239266243288)
print(gradient(x, y, 2, -1))   # should print (10.94724640649514, -462.08205479805036)
# Out:
# (2, 3)
# (3.569176215534111, -163.58239266243288)
# (10.94724640649514, -462.0820547980504)

# %% [markdown]
# # TODO: implement gradient descent
#
# 1. In this cell you will implement gradient descent:
#     * Select a step size
#     * Run for a fixed number of iterations (say, 20 or 200)
#     * Update `theta_0` and `theta_1` using the partial derivatives (**Hint**: use the function ``gradient`` in ``gd.py``)
#     * Record the value of the cost function attained in each iteration of gradient descent so you can examine its progress.

# %%
line, dot, hyp = init_plot()

iters = 50  # change as needed

####################################################################################
# TODO: intialize theta_0, theta_1, step size, and an array to save the cost function
###################################################################################
# To Do Start
theta_0 = 0
theta_1 = 1
learning_rate = 0.01 # step size
cost_history = []
theta_0_history = [theta_0]
theta_1_history = [theta_1]
# To Do End

for i in range(0, iters):
    
    #KEEP THIS CODE: this code will display progress of the 
    #algorithm as it runs 
    clear_output(wait=True)
    update_plot(theta_0, theta_1, line, dot, hyp)
    display(fig)
    
    #################################################################################
    # TODO: 
    #    - write code to get partial derivatives (hint: call gradient in gd.py) 
    #    - update theta_0 and theta_1 with the partial derivatives and step size 
    #    - save cost function at each step (hint: call a function we gave you above)
    #################################################################################
# To Do Start
    for i in range(iters):
        # Compute Gradient
        d_theta_0, d_theta_1 = gradient(x, y, theta_0, theta_1)

        # Update parameters
        theta_0 -= learning_rate * d_theta_0
        theta_1 -= learning_rate * d_theta_1

        # Compute Cost
        cost = cost_function(x, y, theta_0, theta_1)
        cost_history.append(cost)
        theta_0_history.append(theta_0)
        theta_1_history.append(theta_1)

# Results
print("Theta_0 History : ")
print(theta_0_history)
print("Theta_1 History : ")
print(theta_1_history)
print("Cost History : ")
print(cost_history)
print(f"Final theta_0 : {theta_0_history[-1]}, Final theta_1 : {theta_1_history[-1]}")
# To Do End
# Out:
# Theta_0 History :
# [0, -0.03569176215534111, -0.3310638384510407, -0.39338262856149603, -0.5651578957477799, -0.6243042092208166, -0.7275082914059386, -0.7750051478520761, -0.8387381696573334, -0.8741158067801971, -0.9143467586957187, -0.939652089780763, -0.9654768987326572, -0.9831513389730081, -0.9999352104883494, -1.01209889510289, -1.0231046769834613, -1.031397122927157, -1.0386596748382155, -1.044278222893618, -1.049091824416601, -1.0528832021324948, -1.0560833799768332, -1.058634854797257, -1.0607668570619784, -1.0624807963490484, -1.0639032030670186, -1.0650531240056915, -1.0660030391551523, -1.0667739105658758, -1.067408708070403, -1.067925188170511, -1.0683495950570927, -1.068695503632964, -1.0689793369467329, -1.0692109473643654, -1.069400808085425, -1.0695558609080125, -1.0696828798598526, -1.0697866686199573, -1.069871653907902, -1.0699411221716308, -1.0699979874739403, -1.0700444817145989, -1.0700825330763142, -1.0701136499534762, -1.0701391127506068, -1.0701599376106896, -1.070176976876252, -1.0701909136061503, -1.0702023161470495, -1.0702116429913582, -1.0702192735525338, -1.070225515285957, -1.0702306216771265, -1.0702347987632623, -1.070238215988108, -1.0702410113632752, -1.0702432981954848, -1.0702451689023, -1.0702466992704098, -1.0702479511733076, -1.0702489753104052, -1.0702498131002272, -1.0702504984632746, -1.070251059122779, -1.070251517775042, -1.0702518929752554, -1.0702521999103713, -1.0702524509988667, -1.0702526564032655, -1.0702528244346672, -1.0702529618936052, -1.070253074342196, -1.0702531663312784, -1.07025324158319, -1.0702533031433341, -1.0702533535027896, -1.0702533946995432, -1.0702534284006755, -1.070253455970016, -1.0702534785232043, -1.070253496972924, -1.0702535120657786, -1.0702535244125435, -1.0702535345128563, -1.0702535427754536, -1.0702535495346996, -1.070253555064125, -1.0702535595874905, -1.0702535632878458, -1.0702535663149342, -1.0702535687912547, -1.070253570817017, -1.0702535724741993, -1.0702535738298629, -1.0702535749388684, -1.0702535758460943, -1.0702535765882535, -1.0702535771953794, -1.070253577692041, -1.0702535780983367, -1.0702535784307083, -1.0702535787026062, -1.0702535789250331, -1.0702535791069903, -1.070253579255841, -1.0702535793776087, -1.0702535794772212, -1.0702535795587096, -1.0702535796253716, -1.0702535796799046, -1.0702535797245156, -1.0702535797610095, -1.0702535797908637, -1.070253579815286, -1.0702535798352646, -1.0702535798516082, -1.0702535798649782, -1.0702535798759156, -1.070253579884863, -1.0702535798921824, -1.07025357989817, -1.0702535799030684, -1.0702535799070754, -1.0702535799103534, -1.070253579913035, -1.0702535799152286, -1.0702535799170232, -1.0702535799184911, -1.070253579919692, -1.0702535799206745, -1.070253579921478, -1.0702535799221355, -1.0702535799226733, -1.0702535799231132, -1.0702535799234731, -1.0702535799237676, -1.0702535799240085, -1.0702535799242057, -1.0702535799243669, -1.0702535799244988, -1.0702535799246067, -1.0702535799246948, -1.070253579924767, -1.070253579924826, -1.0702535799248742, -1.0702535799249138, -1.070253579924946, -1.0702535799249724, -1.0702535799249941, -1.0702535799250117, -1.0702535799250261, -1.070253579925038, -1.0702535799250477, -1.0702535799250557, -1.070253579925062, -1.0702535799250674, -1.0702535799250719, -1.0702535799250754, -1.0702535799250783, -1.0702535799250807, -1.0702535799250827, -1.0702535799250843, -1.0702535799250856, -1.0702535799250867, -1.0702535799250876, -1.0702535799250883, -1.070253579925089, -1.0702535799250894, -1.0702535799250898, -1.07025357992509, -1.0702535799250903, -1.0702535799250905, -1.0702535799250907, -1.070253579925091, -1.070253579925091, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.0702535799250912, -1.07025 ...
# Theta_1 History :
# [1, 2.6358239266243286, 1.5691864104225866, 2.316660491886262, 1.8367753303756649, 2.179410065560505, 1.9644233403285485, 2.1222039302507083, 2.0265089151935847, 2.0996427995901197, 2.057466076829427, 2.0916795284340743, 2.073376460904714, 2.0895883731891183, 2.0818425861978014, 2.0896583971961165, 2.0865183036225026, 2.0903721231836476, 2.089198106351626, 2.091152393424934, 2.090787586665549, 2.0918119017358197, 2.091758762911123, 2.092315581032637, 2.092366696802561, 2.0926809350380937, 2.092754477985228, 2.092938270904273, 2.093005338004343, 2.0931163086063527, 2.093169291961642, 2.0932380972503597, 2.0932772308432726, 2.093320799406589, 2.093348656536097, 2.093376689132453, 2.0933960886330856, 2.0934143382816357, 2.0934276642782597, 2.0934396456654585, 2.093448719520878, 2.0934566325495303, 2.0934627756490767, 2.0934680234636196, 2.0934721666139104, 2.093475656875856, 2.0934784440952563, 2.0934807699999363, 2.093482641853934, 2.0934841939201796, 2.093485449588317, 2.0934864862267357, 2.0934873278966393, 2.093488020709306, 2.0934885845827553, 2.093489047804505, 2.093489425435693, 2.0934897352400257, 2.093489988082501, 2.093490195321361, 2.093490364584247, 2.093490503231957, 2.093490616530857, 2.093490709297839, 2.0934907851306708, 2.0934908472033893, 2.093490897956996, 2.093490939493137, 2.093490973460487, 2.0934910012553014, 2.093491023987756, 2.093491042587617, 2.093491057800943, 2.0934910702478446, 2.0934910804290072, 2.093491088758463, 2.093491095571918, 2.0934911011460167, 2.093491105705706, 2.0934911094359254, 2.0934911124873437, 2.0934911149836353, 2.0934911170256894, 2.0934911186962295, 2.0934911200628004, 2.093491121180742, 2.093491122095269, 2.093491122843407, 2.0934911234554203, 2.093491123956082, 2.0934911243656487, 2.0934911247006975, 2.093491124974784, 2.0934911251990025, 2.093491125382424, 2.093491125532474, 2.0934911256552224, 2.093491125755637, 2.0934911258377817, 2.09349112590498, 2.0934911259599525, 2.0934911260049223, 2.0934911260417106, 2.0934911260718048, 2.0934911260964237, 2.0934911261165636, 2.0934911261330384, 2.0934911261465166, 2.093491126157542, 2.0934911261665614, 2.0934911261739395, 2.093491126179976, 2.093491126184913, 2.093491126188953, 2.093491126192257, 2.09349112619496, 2.093491126197171, 2.0934911261989804, 2.09349112620046, 2.0934911262016707, 2.093491126202661, 2.0934911262034714, 2.0934911262041336, 2.0934911262046763, 2.0934911262051195, 2.0934911262054827, 2.093491126205779, 2.0934911262060223, 2.093491126206221, 2.093491126206383, 2.093491126206516, 2.0934911262066245, 2.0934911262067137, 2.0934911262067866, 2.0934911262068456, 2.093491126206895, 2.0934911262069344, 2.093491126206967, 2.093491126206994, 2.0934911262070153, 2.0934911262070335, 2.093491126207048, 2.09349112620706, 2.0934911262070695, 2.093491126207078, 2.093491126207084, 2.09349112620709, 2.093491126207094, 2.0934911262070974, 2.0934911262071005, 2.0934911262071028, 2.093491126207105, 2.0934911262071063, 2.093491126207108, 2.0934911262071085, 2.09349112620711, 2.0934911262071103, 2.093491126207111, 2.093491126207111, 2.093491126207112, 2.093491126207112, 2.0934911262071125, 2.0934911262071125, 2.093491126207113, 2.093491126207113, 2.0934911262071134, 2.093491126207113, 2.0934911262071134, 2.0934911262071134, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134, 2.093491126207114, 2.0934911262071134,  ...
# Cost History :
# [57.62770196139053, 35.323522602699434, 24.5933105739712, 19.316757612892793, 16.649804138835428, 15.257228551370185, 14.503280141985709, 14.079499665742198, 13.832556130407585, 13.68393354391086, 13.59202283002933, 13.533941112249163, 13.496626939621677, 13.472361456035449, 13.456442925695114, 13.445935379708681, 13.438969556956563, 13.434337876617505, 13.431251884889603, 13.429192867485613, 13.427817746564873, 13.42689876923986, 13.426284355116751, 13.425873443544264, 13.425598575428733, 13.425414684359858, 13.425291646770825, 13.42520931968608, 13.42515423048363, 13.425117366437556, 13.42509269762901, 13.42507618944802, 13.425065142196274, 13.425057749344784, 13.42505280200722, 13.425049491211785, 13.42504727559832, 13.425045792888335, 13.425044800643562, 13.425044136622759, 13.42504369225276, 13.425043394875395, 13.425043195867117, 13.425043062688518, 13.425042973563874, 13.425042913920644, 13.425042874006706, 13.425042847295844, 13.425042829420633, 13.425042817458325, 13.425042809453016, 13.42504280409577, 13.425042800510633, 13.425042798111429, 13.425042796505844, 13.425042795431377, 13.425042794712324, 13.425042794231128, 13.425042793909105, 13.425042793693608, 13.425042793549391, 13.425042793452885, 13.425042793388293, 13.425042793345067, 13.425042793316145, 13.425042793296788, 13.425042793283838, 13.425042793275166, 13.425042793269368, 13.425042793265487, 13.425042793262893, 13.42504279326115, 13.425042793259982, 13.425042793259209, 13.425042793258683, 13.425042793258335, 13.4250427932581, 13.425042793257948, 13.425042793257841, 13.42504279325777, 13.42504279325773, 13.425042793257695, 13.425042793257676, 13.425042793257655, 13.42504279325765, 13.425042793257646, 13.425042793257642, 13.425042793257639, 13.425042793257633, 13.425042793257637, 13.425042793257633, 13.42504279325763, 13.425042793257633, 13.425042793257632, 13.425042793257633, 13.425042793257633, 13.42504279325763, 13.42504279325763, 13.42504279325763, 13.425042793257632, 13.425042793257628, 13.425042793257635, 13.425042793257633, 13.425042793257633, 13.425042793257633, 13.425042793257633, 13.425042793257626, 13.42504279325763, 13.425042793257632, 13.425042793257623, 13.42504279325763, 13.425042793257633, 13.425042793257633, 13.42504279325763, 13.425042793257637, 13.425042793257632, 13.42504279325763, 13.425042793257635, 13.425042793257637, 13.425042793257626, 13.425042793257628, 13.425042793257628, 13.425042793257632, 13.42504279325763, 13.425042793257633, 13.425042793257626, 13.425042793257628, 13.425042793257632, 13.425042793257632, 13.425042793257635, 13.425042793257632, 13.425042793257628, 13.425042793257633, 13.425042793257628, 13.425042793257632, 13.42504279325763, 13.42504279325763, 13.425042793257632, 13.425042793257632, 13.425042793257633, 13.425042793257626, 13.425042793257632, 13.425042793257628, 13.425042793257632, 13.425042793257632, 13.42504279325763, 13.425042793257633, 13.425042793257635, 13.425042793257635, 13.425042793257628, 13.425042793257633, 13.425042793257633, 13.425042793257628, 13.42504279325763, 13.425042793257633, 13.425042793257628, 13.425042793257632, 13.425042793257633, 13.425042793257637, 13.425042793257635, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.42504279325763, 13.42504279325763, 13.42504279325763, 13.425042793257632, 13.42504279325763, 13.425042793257633, 13.425042793257632, 13.42504279325763, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257626, 13.425042793257628, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.425042793257632, 13.42504279325763 ...
# Final theta_0 : -1.0702535799250912, Final theta_1 : 2.093491126207114

# %% [markdown]
# # TODO: compare gradient descent thetas with explicit thetas
# complete ``explicit_answer`` function in ``gd.py`` and print results of both ways.

# %%
############################################
# TODO: Write code print both results
# To Do Start
explicit_theta_0, explicit_theta_1 = explicit_answer(x, y)
print(f"Explicit Theta_0 = {explicit_theta_0} and Theta_0 = {theta_0_history[-1]}")
print(f"Explicit Theta_1 = {explicit_theta_1} and Theta_1 = {theta_1_history[-1]}")
# To Do End
###########################################
# Out:
# Explicit Theta_0 = -1.0702535799250916 and Theta_0 = -1.0702535799250912
# Explicit Theta_1 = 2.093491126207114 and Theta_1 = 2.093491126207114

# %% [markdown]
# # TODO: assess convergence
# Plot the iteration (x-axis) vs. cost.

# %%
############################################
# TODO: Write code to plot and display here
###########################################

# %% [markdown]
#  Did the algorithm converge? (Converging means it found the actual setting of $\theta$ that minimizes the cost. If the cost went up or did not go down as far as it could, it did not converge.)

# %% [markdown]
# ** *Write your answer here*. **

# %% [markdown]
# # TODO: experiment with step size
#
# After you have completed the implementation, do some experiments with different numbers of iterations and step sizes to assess convergence of the algorithm. Report the following:
# * A step size for which the algorithm converges to the minimum in at most 200 iterations
# * A step size for which the algorithm converges, but it takes more than 200 iterations
# * A step size for which the algorithm does not converge, no matter how many iterations are run

# %%
############################################
# TODO: Put experimental code here 
###########################################

# %% [markdown]
# ** *Write your answer here*. **
